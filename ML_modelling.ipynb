# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("DF_for_ML.csv")

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet

# %%
X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
y = df[["median_house_value"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Linear Regression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train_scaled,y_train)
y_pred = lin_reg.predict(X_test_scaled)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2_score = r2_score(y_test,y_pred)
print(f"Mean absolute Error : {mae}")
print(f"Prediction Accuracy: {r2_score}")
# Out:
# Mean absolute Error : 5.146770999327588
# Prediction Accuracy: 0.6479959708743142

# %%
from sklearn.linear_model import RidgeCV
ridge_reg = RidgeCV()
ridge_reg.fit(X_train_scaled,y_train)
y_pred = ridge_reg.predict(X_test_scaled)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2_score = r2_score(y_test,y_pred)
print(f"Mean absolute Error : {mae}")
print(f"Prediction Accuracy: {r2_score}")
# Out:
# Mean absolute Error : 5.146721187640247
# Prediction Accuracy: 0.6479872824326229

# %%
from sklearn.linear_model import ElasticNetCV
ridge_reg = ElasticNetCV()
ridge_reg.fit(X_train_scaled,y_train)
y_pred = ridge_reg.predict(X_test_scaled)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2_score = r2_score(y_test,y_pred)
print(f"Mean absolute Error : {mae}")
print(f"Prediction Accuracy: {r2_score}")
# Out:
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean absolute Error : 5.1498127150418584
# Prediction Accuracy: 0.6459347578599139

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv = ElasticNet()
elasticcv.fit(X_train_scaled,y_train)
y_pred = elasticcv.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print(f"Mean absolute Error : {mae}")
print(f"Prediction Accuracy: {score}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       4 y_pred = elasticcv.predict(X_test_scaled)
#       5 mae = mean_absolute_error(y_test,y_pred)
# ----> 6 score = r2_score(y_test,y_pred)
#       7 print(f"Mean absolute Error : {mae}")
#       8 print(f"Prediction Accuracy: {score}")
#
# TypeError: 'float' object is not callable

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train_poly,y_train)
y_pred = lin_reg.predict(X_test_poly)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2_score = r2_score(y_test,y_pred)
print(f"Mean absolute Error : {mae}")
print(f"Prediction Accuracy: {r2_score}")
# Out:
# Mean absolute Error : 4.518514554047207
# Prediction Accuracy: 0.7094135384326719

# %% [markdown]
# ## Function to find the best model

# %%
def Model_predict():
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    from sklearn.linear_model import LinearRegression,Ridge,Lasso
    model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
    model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
    Results = {}
    for i in range(len(model_lst)):
        model = model_lst[i]()
        model.fit(X_train_poly,y_train)
        y_pred = model.predict(X_test_poly)
        # Performance Metrics
        mse = mean_squared_error(y_test,y_pred)
        mae = mean_absolute_error(y_test,y_pred)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_test,y_pred)
        Results[str(model_name[i])] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
# Out:
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.45069e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.160e+05, tolerance: 2.023e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.138e+05, tolerance: 2.023e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
for item in Results.items():
    print(item)
# Out:
# ('lin_reg', {'mse': 39.90882512967446, 'mae': 4.518514554047207, 'rmse': 6.317343201827368, 'r2_score': 0.7094135384326719})
# ('Ridge_reg', {'mse': 40.05803427172589, 'mae': 4.553239059083254, 'rmse': 6.329141669430847, 'r2_score': 0.7083271081385869})
# ('Lasso_reg', {'mse': 42.23304772950703, 'mae': 4.744111572639451, 'rmse': 6.498695848361194, 'r2_score': 0.6924902734910043})
# ('Elastic_reg', {'mse': 42.10417702445055, 'mae': 4.737434369183733, 'rmse': 6.488773152488115, 'r2_score': 0.6934286143732621})

# %%
predict_model_result = {}
cross_valid_result = {}

def Model_predict():
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    from sklearn.linear_model import LinearRegression,Ridge,Lasso
    model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
    model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
    Results = {}
    for i in range(len(model_lst)):
        model = model_lst[i]()
        model.fit(X_train_poly,y_train)
        y_pred = model.predict(X_test_poly)
        # Performance Metrics
        mse = mean_squared_error(y_test,y_pred)
        mae = mean_absolute_error(y_test,y_pred)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_test,y_pred)
        predict_model_result[str(model_name[i])] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}


def Cross_Valid():
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    from sklearn.linear_model import LinearRegression,RidgeCV,LassoCV,ElasticNetCV
    cv_model_lst = [RidgeCV,LassoCV,ElasticNetCV]
    cv_model_name = ["Ridge_CV","Lasso_CV","Elastic_CV"]
    #Results = {}
    for i in range(len(cv_model_lst)):
        model = cv_model_lst[i]()
        model.fit(X_train_poly,y_train)
        y_pred = model.predict(X_test_poly)
        # Performance Metrics
        mse = mean_squared_error(y_test,y_pred)
        mae = mean_absolute_error(y_test,y_pred)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_test,y_pred)
        cross_valid_result[str(cv_model_name[i])] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

Model_predict()
Cross_Valid()

print("-----MODEL DETAILS: ------")
for item in predict_model_result.items():
    print(item)
print("\n\n-----CV DETAILS: ------")
for item in predict_model_result.items():
    print(item)
# Out:
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# -----MODEL DETAILS: ------
# ('lin_reg', {'mse': 39.90882528202718, 'mae': 4.518514563467736, 'rmse': 6.317343213885659, 'r2_score': 0.7094135373233524})
# ('Ridge_reg', {'mse': 39.89891970890228, 'mae': 4.51842340049051, 'rmse': 6.316559166896347, 'r2_score': 0.7094856623592263})
# ('Lasso_reg', {'mse': 67.92244534820684, 'mae': 6.241999548698647, 'rmse': 8.241507468188502, 'r2_score': 0.505439135564534})
# ('Elastic_reg', {'mse': 75.18384435550439, 'mae': 6.66521721972357, 'rmse': 8.670861800046428, 'r2_score': 0.45256701425545165})
#
#
# -----CV DETAILS: ------
# ('lin_reg', {'mse': 39.90882528202718, 'mae': 4.518514563467736, 'rmse': 6.317343213885659, 'r2_score': 0.7094135373233524})
# ('Ridge_reg', {'mse': 39.89891970890228, 'mae': 4.51842340049051, 'rmse': 6.316559166896347, 'r2_score': 0.7094856623592263})
# ('Lasso_reg', {'mse': 67.92244534820684, 'mae': 6.241999548698647, 'rmse': 8.241507468188502, 'r2_score': 0.505439135564534})
# ('Elastic_reg', {'mse': 75.18384435550439, 'mae': 6.66521721972357, 'rmse': 8.670861800046428, 'r2_score': 0.45256701425545165})

# %%
for item in predict_model_result.items():
    print(item)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X_train_scaled)
X_test_poly = poly.transform(X_test_scaled)

# %%
predict_model_result = {}
cross_valid_result = {}

def Model_predict():
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    from sklearn.linear_model import LinearRegression,Ridge,Lasso
    model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
    model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
    Results = {}
    for i in range(len(model_lst)):
        model = model_lst[i]()
        model.fit(X_train_poly,y_train)
        y_pred_train = model.predict(X_train_poly)
        y_pred_test = model.predict(X_test_poly)
        # Performance Metrics for testing data
        mse = mean_squared_error(y_test,y_pred_test)
        mae = mean_absolute_error(y_test,y_pred_test)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_test,y_pred_test)
        predict_model_result[str(model_name[i])+"TESTING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

        # Performance Metrics for training data
        mse = mean_squared_error(y_train,y_pred_train)
        mae = mean_absolute_error(y_train,y_pred_train)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_train,y_pred_train)
        predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}




def Cross_Valid():
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    from sklearn.linear_model import LinearRegression,RidgeCV,LassoCV,ElasticNetCV
    cv_model_lst = [RidgeCV,LassoCV,ElasticNetCV]
    cv_model_name = ["Ridge_CV","Lasso_CV","Elastic_CV"]
    #Results = {}
    for i in range(len(cv_model_lst)):
        model = cv_model_lst[i]()
        model.fit(X_train_poly,y_train)
        y_pred = model.predict(X_test_poly)
        # Performance Metrics
        mse = mean_squared_error(y_test,y_pred)
        mae = mean_absolute_error(y_test,y_pred)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_test,y_pred)
        cross_valid_result[str(cv_model_name[i])] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

Model_predict()
Cross_Valid()

print("-----MODEL DETAILS: ------")
for item in predict_model_result.items():
    print(item)
print("\n\n-----CV DETAILS: ------")
for item in predict_model_result.items():
    print(item)
# Out:
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.326e+05, tolerance: 2.023e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.239e+05, tolerance: 2.023e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 724.9140873064753, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1072.6037849752465, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1626.2217257284792, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3651.686660197214, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4040.376300616772, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4419.539595276117, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12152.640534242732, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10738.744634898729, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10700.874449320254, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1159.6334866994293, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1752.680878503248, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9150.716969735455, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10516.44419954787, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28184.31058683351, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54434.46643845737, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 613.3980100485496, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 440.1098299721489, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2242.040085053304, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 570.5232176615391, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7972.187564987806, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13579.928107669111, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6422.818990918226, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 284.0320063851541, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 441.69633831689134, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2153.628021103912, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11382.914809937589, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23577.251370823476, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26002.851000641123, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5742.113489001407, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10682.090381674585, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1824.5386664702091, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2306.818102039746, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3140.1993419205537, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178.5828920576023, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 383.0882603357313, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 616.9906856318703, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 884.0990850818343, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3168.608507419587, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8226.096477103885, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15720.184577315813, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25757.939788794843, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19495.06919886719, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12736.424584872322, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 438.08818052802235, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 165.1357854155358, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323.55139439343475, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 638.033119107713, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 298.84839890815783, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 614.4945735854562, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 453.7706629681634, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1419.6432370407274, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2183.7150812263135, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3295.7387587855337, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5522.849736106349, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3384.5511747297132, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6670.830574992695, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6359.8772607585415, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13585.787792203948, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41906.75756766135, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39355.45907389163, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324.73889907926787, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 723.96059499064, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1501.815931799123, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3170.1823468544753, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4949.5964063426945, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5989.822793867672, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1566.979424860794, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5155.813476616982, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.016e+05, tolerance: 2.023e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 416.08050700835884, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1176.3002599024912, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1486.179108967539, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1766.3191787516698, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5113.452380792936, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5724.110372361494, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3502.9249393061036, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1532.5900895007653, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3068.0076182466, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4340.595067090704, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4310.812008174718, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5243.936773619498, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4588.156159551814, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4776.926308216993, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12609.35837618832, tolerance: 162.82894599590384
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179.15510853473097, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 479.153589862166, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 494.3097240634961, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 425.4495197167853, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306.51931941870134, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 959.2189808383118, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1055.3262712596916, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1565.2122078542598, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2403.743368690484, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1949.3168306604493, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4099.459133698838, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3994.4838764744345, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3868.6185899131233, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5879.562517281622, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14624.729182810406, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6707.937929683481, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3724.974520321586, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9561.045444562798, tolerance: 162.8585138151823
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.10741264757235, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201.5264061393682, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193.57579873816576, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3118.3486321949167, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3383.8451799448812, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 530.1861263503088, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250.29767484776676, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308.4963605721714, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 372.3348138453439, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 396.50868961715605, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 443.29566135897767, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 639.6481167692691, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3201.222717379569, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5746.564264694927, tolerance: 160.14451199425875
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176.25624755921308, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 536.7692219524179, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 767.597789380583, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 493.1304236052092, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3189.074466726044, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3500.9197155409493, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4602.370394818718, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3859.6765837551793, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9408.164142546011, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11097.17470693076, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18177.098240035586, tolerance: 160.77434136884284
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 358.357494255295, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 616.5418493559118, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 556.7388151282212, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 372.0370475030504, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 861.4320911585819, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1879.4728954641614, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1881.321671397076, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2839.446443045046, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1449.4719614099013, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.7046499962453, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 337.67529823537916, tolerance: 162.4224274519814
#   model = cd_fast.enet_coordinate_descent_gram(
# -----MODEL DETAILS: ------
# ('lin_reg', {'mse': 13603.064581636803, 'mae': 6.081626989866427, 'rmse': 116.63217644216712, 'r2_score': -98.04742598675264})
# ('Ridge_reg', {'mse': 5907.385504870324, 'mae': 5.217960686102696, 'rmse': 76.85951798489452, 'r2_score': -42.01319934617664})
# ('Lasso_reg', {'mse': 63.09514332499883, 'mae': 5.876901939606572, 'rmse': 7.943245138166065, 'r2_score': 0.5405879681669199})
# ('Elastic_reg', {'mse': 63.153332563879864, 'mae': 5.910689910586818, 'rmse': 7.946907106785624, 'r2_score': 0.5401642772922125})
#
#
# -----CV DETAILS: ------
# ('lin_reg', {'mse': 13603.064581636803, 'mae': 6.081626989866427, 'rmse': 116.63217644216712, 'r2_score': -98.04742598675264})
# ('Ridge_reg', {'mse': 5907.385504870324, 'mae': 5.217960686102696, 'rmse': 76.85951798489452, 'r2_score': -42.01319934617664})
# ('Lasso_reg', {'mse': 63.09514332499883, 'mae': 5.876901939606572, 'rmse': 7.943245138166065, 'r2_score': 0.5405879681669199})
# ('Elastic_reg', {'mse': 63.153332563879864, 'mae': 5.910689910586818, 'rmse': 7.946907106785624, 'r2_score': 0.5401642772922125})
# /home/monoitachi/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.283e+04, tolerance: 2.023e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
predict_model_result = {}

def Model_predict():
    from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
    from sklearn.linear_model import LinearRegression,Ridge,Lasso
    model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
    model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
    Results = {}
    for i in range(len(model_lst)):
        model = model_lst[i]()
        model.fit(X_train_poly,y_train)
        y_pred = model.predict(X_test_poly)
        # Performance Metrics
        mse = mean_squared_error(y_test,y_pred)
        mae = mean_absolute_error(y_test,y_pred)
        rmse = np.sqrt(mse)
        n_score = r2_score(y_test,y_pred)
        predict_model_result[str(model_name[i])] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

Model_predict()

print("-----MODEL DETAILS: ------")
for item in predict_model_result.items():
    print(item)
# Out:
# -----MODEL DETAILS: ------
# ('lin_reg', {'mse': 35.748362089803095, 'mae': 4.246352036864197, 'rmse': 5.978993401050305, 'r2_score': 0.7397069441971762})
# ('Ridge_reg', {'mse': 35.767333392893136, 'mae': 4.24666426945682, 'rmse': 5.980579687028101, 'r2_score': 0.7395688092403503})
# ('Lasso_reg', {'mse': 62.71159735847501, 'mae': 5.948014699497038, 'rmse': 7.919065434663046, 'r2_score': 0.543380665393622})
# ('Elastic_reg', {'mse': 67.33896658977216, 'mae': 6.156939631071717, 'rmse': 8.20603232931556, 'r2_score': 0.5096875950784965})

# %% [markdown]
# # Final Function with 73-74% accuracy in testing as well as training before Accuracy Optimization

# %%
def main(df):
    from sklearn.preprocessing import PolynomialFeatures


    X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
    y = df[["median_house_value"]]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    poly = PolynomialFeatures(degree=3)
    X_train_poly = poly.fit_transform(X_train_scaled)
    X_test_poly = poly.transform(X_test_scaled)


    predict_model_result = {}

    def Model_predict():
        from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
        from sklearn.linear_model import LinearRegression,Ridge,Lasso
        model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
        model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
        Results = {}
        for i in range(len(model_lst)):
            model = model_lst[i]()
            model.fit(X_train_poly,y_train)
            y_pred_train = model.predict(X_train_poly)
            y_pred_test = model.predict(X_test_poly)
            # Performance Metrics for testing data
            mse = mean_squared_error(y_test,y_pred_test)
            mae = mean_absolute_error(y_test,y_pred_test)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_test,y_pred_test)
            predict_model_result[str(model_name[i])+"TESTING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

            # Performance Metrics for training data
            mse = mean_squared_error(y_train,y_pred_train)
            mae = mean_absolute_error(y_train,y_pred_train)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_train,y_pred_train)
            predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

    Model_predict()

    print("-----MODEL DETAILS: ------")
    for item in predict_model_result.items():
        print(item)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.24     37.85                  52         1467             190
# 3    -122.25     37.85                  52         1274             235
# 4    -122.25     37.85                  52         1627             280
#
#    population  households  median_income  median_house_value
# 0         322         126         8.3252               45.26
# 1        2401        1138         8.3014               35.85
# 2         496         177         7.2574               35.21
# 3         558         219         5.6431               34.13
# 4         565         259         3.8462               34.22

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df_copy = df.copy()

# %%
df_copy.skew()
# Out:
# longitude            -0.291306
# latitude              0.459146
# housing_median_age    0.054117
# total_rooms           2.010251
# total_bedrooms        1.936505
# population            1.338558
# households            1.617033
# median_income         1.659229
# median_house_value    0.974804
# dtype: float64

# %%
lst = ["total_rooms","total_bedrooms","population","households","median_income"]

# %%
for col in lst:
    df_copy[col] = np.log(df_copy[col]+1)

# %%
df_copy.skew()
# Out:
# longitude            -0.291306
# latitude              0.459146
# housing_median_age    0.054117
# total_rooms          -1.369575
# total_bedrooms       -1.279107
# population           -1.371833
# households           -1.330222
# median_income         0.232245
# median_house_value    0.974804
# dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.histplot(df["total_rooms"])
# Out:
# <Axes: xlabel='total_rooms', ylabel='Count'>

# %%
sns.histplot(df["total_bedrooms"])
# Out:
# <Axes: xlabel='total_bedrooms', ylabel='Count'>

# %%
# Remove outliers based on Z-score for 'total_rooms' and 'total_bedrooms'
from scipy.stats import zscore
zscore_rooms = zscore(df["total_rooms"])
zscore_bedrooms = zscore(df["total_bedrooms"])
df_cleaned = df[(abs(zscore_rooms) <= 3) & (abs(zscore_bedrooms) <= 3)]

# %%
df_cleaned
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880             129
# 1        -122.22     37.86                  21         7099            1106
# 2        -122.24     37.85                  52         1467             190
# 3        -122.25     37.85                  52         1274             235
# 4        -122.25     37.85                  52         1627             280
# ...          ...       ...                 ...          ...             ...
# 20293    -121.09     39.48                  25         1665             374
# 20294    -121.21     39.49                  18          697             150
# 20295    -121.22     39.43                  17         2254             485
# 20296    -121.32     39.43                  18         1860             409
# 20297    -121.24     39.37                  16         2785             616
#
#        population  households  median_income  median_house_value
# 0             322         126         8.3252               45.26
# 1            2401        1138         8.3014               35.85
# 2             496         177         7.2574               35.21
# 3             558         219         5.6431               34.13
# 4             565         259         3.8462               34.22
# ...           ...         ...            ...                 ...
# 20293         845         330         1.5603                7.81
# 20294         356         114         2.5568                7.71
# 20295        1007         433         1.7000                9.23
# 20296         741         349         1.8672                8.47
# 20297        1387         530         2.3886                8.94
#
# [19766 rows x 9 columns]

# %%
plt.figure(figsize=(15,6))
sns.boxplot(df_cleaned)
# Out:
# <Axes: >

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile) for 'total_rooms' and 'total_bedrooms'
Q1_rooms = df['total_rooms'].quantile(0.25)
Q3_rooms = df['total_rooms'].quantile(0.75)
Q1_bedrooms = df['total_bedrooms'].quantile(0.25)
Q3_bedrooms = df['total_bedrooms'].quantile(0.75)

# Calculate IQR for both columns
IQR_rooms = Q3_rooms - Q1_rooms
IQR_bedrooms = Q3_bedrooms - Q1_bedrooms

# Define outlier conditions for both columns
lower_bound_rooms = Q1_rooms - 1.5 * IQR_rooms
upper_bound_rooms = Q3_rooms + 1.5 * IQR_rooms
lower_bound_bedrooms = Q1_bedrooms - 1.5 * IQR_bedrooms
upper_bound_bedrooms = Q3_bedrooms + 1.5 * IQR_bedrooms

# Identify outliers in both columns
outliers_rooms = df[(df['total_rooms'] < lower_bound_rooms) | (df['total_rooms'] > upper_bound_rooms)]
outliers_bedrooms = df[(df['total_bedrooms'] < lower_bound_bedrooms) | (df['total_bedrooms'] > upper_bound_bedrooms)]

# Display outliers
print("Outliers in Total Rooms:")
print(outliers_rooms)
print("\nOutliers in Total Bedrooms:")
print(outliers_bedrooms)
# Out:
# Outliers in Total Rooms:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -122.22     37.86                  21         7099            1106
# 101      -122.25     37.81                  28         5806            1603
# 104      -122.26     37.81                  34         5871            1914
# 185      -122.23     37.79                  43         5963            1344
# 507      -122.30     37.84                  14         7355            2408
# ...          ...       ...                 ...          ...             ...
# 20194    -121.67     38.54                  13         6141            1019
# 20200    -121.71     38.56                  20         8627            1516
# 20202    -121.70     38.54                  13         6819            1158
# 20204    -121.74     38.55                  33         6861            1820
# 20226    -121.79     38.66                  15         6809            1052
#
#        population  households  median_income  median_house_value
# 1            2401        1138         8.3014               35.85
# 101          2563        1497         3.2177               27.34
# 104          2689        1789         2.8406               33.57
# 185          4367        1231         2.1917               11.28
# 507          3100        2051         4.0018               14.38
# ...           ...         ...            ...                 ...
# 20194        2553         967         4.2432               32.65
# 20200        4071        1466         4.2198               16.41
# 20202        2828        1115         4.6225               22.65
# 20204        3717        1767         1.7311               18.26
# 20226        3060        1060         5.3064               16.50
#
# [1070 rows x 9 columns]
#
# Outliers in Total Bedrooms:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 95       -122.26     37.80                  36         5329            2477
# 96       -122.26     37.82                  31         4596            1331
# 98       -122.26     37.82                  22         3682            1270
# 100      -122.25     37.81                  29         4656            1414
# 101      -122.25     37.81                  28         5806            1603
# ...          ...       ...                 ...          ...             ...
# 20187    -121.55     38.55                  10         6227            1164
# 20195    -121.74     38.56                  18         3960            1151
# 20200    -121.71     38.56                  20         8627            1516
# 20202    -121.70     38.54                  13         6819            1158
# 20204    -121.74     38.55                  33         6861            1820
#
#        population  households  median_income  median_house_value
# 95           3469        2323         2.0096               13.00
# 96           2048        1180         2.8345               18.38
# 98           2024        1250         1.2185               17.00
# 100          2304        1250         2.4912               25.78
# 101          2563        1497         3.2177               27.34
# ...           ...         ...            ...                 ...
# 20187        2909        1077         4.1060               11.59
# 20195        2248        1144         1.7257               17.91
# 20200        4071        1466         4.2198               16.41
# 20202        2828        1115         4.6225               22.65
# 20204        3717        1767         1.7311               18.26
#
# [1061 rows x 9 columns]

# %%
# Remove outliers using IQR method for 'total_rooms' and 'total_bedrooms'
df_cleaned = df[
    (df['total_rooms'] >= lower_bound_rooms) & (df['total_rooms'] <= upper_bound_rooms) & 
    (df['total_bedrooms'] >= lower_bound_bedrooms) & (df['total_bedrooms'] <= upper_bound_bedrooms)
]

# %%
plt.figure(figsize=(15,6))
sns.boxplot(df_cleaned)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,6))
sns.boxplot(df_cleaned)

# %%
main(df_cleaned)
# Out:
# -----MODEL DETAILS: ------
# ('lin_regTESTING', {'mse': 34.02630973861589, 'mae': 4.11763163368357, 'rmse': 5.833207500047971, 'r2_score': 0.7531098250455314})
# ('lin_regTRAINING', {'mse': 33.34840592307532, 'mae': 4.107479982344717, 'rmse': 5.774807868931686, 'r2_score': 0.7457507337089591})
# ('Ridge_regTESTING', {'mse': 34.01838833642074, 'mae': 4.118028277732225, 'rmse': 5.8325284685478165, 'r2_score': 0.7531673016390518})
# ('Ridge_regTRAINING', {'mse': 33.35261405965621, 'mae': 4.107476725587543, 'rmse': 5.775172210389592, 'r2_score': 0.7457186507470144})
# ('Lasso_regTESTING', {'mse': 60.99295531272258, 'mae': 5.859128966832941, 'rmse': 7.8097986729955196, 'r2_score': 0.5574435922136318})
# ('Lasso_regTRAINING', {'mse': 59.81839417906225, 'mae': 5.77172915185374, 'rmse': 7.73423520324164, 'r2_score': 0.5439427340000326})
# ('Elastic_regTESTING', {'mse': 65.89465749431004, 'mae': 6.077710856666125, 'rmse': 8.11755243249528, 'r2_score': 0.5218775223552419})
# ('Elastic_regTRAINING', {'mse': 64.0832060180105, 'mae': 5.996072547581266, 'rmse': 8.005198686979012, 'r2_score': 0.51142767815529})

# %%
Q1_population = df["population"].quantile(0.25)
Q3_population = df["population"].quantile(0.75)

Q1_households = df["households"].quantile(0.25)
Q3_households = df["households"].quantile(0.75)

IQR_pop = Q3_population-Q1_households
IQR_households = Q3_households-Q1_households

lower_fence_pop = Q1_population-1.5*(IQR_pop)
upper_fence_pop = Q3_population+1.5*(IQR_pop)

lower_fence_households = Q1_households-1.5*(IQR_households)
upper_fence_households = Q3_households+1.5*(IQR_households)

# %%
new_cleaned_Df = df_cleaned[
    (df_cleaned["population"]>=lower_fence_pop )& (df_cleaned["population"]<=upper_fence_pop) &
    (df_cleaned["households"]>=lower_fence_households) & (df_cleaned["households"]<=upper_fence_households)
]

# %%
df_copy = new_cleaned_Df.copy()
df_copy.to_csv("Final_csv.csv",index=False)

# %%
list([df_copy.iloc[1]])
# Out:
# [longitude             -122.2400
#  latitude                37.8500
#  housing_median_age      52.0000
#  total_rooms           1467.0000
#  total_bedrooms         190.0000
#  population             496.0000
#  households             177.0000
#  median_income            7.2574
#  median_house_value      35.2100
#  Name: 2, dtype: float64]

# %%
def main(df,test_df):
    from sklearn.preprocessing import PolynomialFeatures


    X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
    y = df[["median_house_value"]]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    poly = PolynomialFeatures(degree=2)
    X_train_poly = poly.fit_transform(X_train_scaled)
    X_test_poly = poly.transform(X_test_scaled)


    predict_model_result = {}

    def Model_predict():
        from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
        from sklearn.linear_model import LinearRegression,Ridge,Lasso
        model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
        model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
        Results = {}
        for i in range(len(model_lst)):
            model = model_lst[i]()
            model.fit(X_train_poly,y_train)
            y_pred_train = model.predict(X_train_poly)
            y_pred_test = model.predict(X_test_poly)
            # Performance Metrics for testing data
            mse = mean_squared_error(y_test,y_pred_test)
            mae = mean_absolute_error(y_test,y_pred_test)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_test,y_pred_test)
            predict_model_result[str(model_name[i])+"TESTING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

            # Performance Metrics for training data
            mse = mean_squared_error(y_train,y_pred_train)
            mae = mean_absolute_error(y_train,y_pred_train)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_train,y_pred_train)
            predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
            # Checking for random data
            new_pred = model.predict(poly.transform(scaler.transform(test_df)))
            print(new_pred)

    Model_predict()

    print("-----MODEL DETAILS: ------")
    for item in predict_model_result.items():
        print(item)

# %%
li = pd.DataFrame([{
    'longitude': -122.23,
    'latitude': 41.88,
    'housing_median_age': 76,
    'total_rooms': 122,
    'total_bedrooms': 252,
    'population': 1000,
    'households': 233,
    'median_income': 16.3252,
}])

# %%
main(df_copy,li)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 main(df_copy,li)
#
# Cell In[136], line 47, in main(df, test_df)
#      44         new_pred = model.predict(scaler.transform(test_df))
#      45         print(new_pred)
# ---> 47 Model_predict()
#      49 print("-----MODEL DETAILS: ------")
#      50 for item in predict_model_result.items():
#
# Cell In[136], line 44, in main.<locals>.Model_predict()
#      42 predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
#      43 # Checking for random data
# ---> 44 new_pred = model.predict(scaler.transform(test_df))
#      45 print(new_pred)
#
# File ~/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File ~/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~/Projects/California_House_price/venv/lib/python3.10/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 8 features, but LinearRegression is expecting 45 features as input.

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8280     -118.35     33.97                  30     7.345365        5.802118
# 14925    -117.09     32.91                   9     7.607381        5.758902
# 19247    -120.94     37.60                  30     8.088869        6.354370
# 753      -122.04     37.66                  23     7.791523        5.855072
# 1418     -122.01     37.98                  29     7.601902        5.924256
#
#        population  households  median_income
# 8280     6.630683    5.857933       1.569782
# 14925    6.688355    5.669881       2.024272
# 19247    7.498316    6.378426       1.511406
# 753      6.972606    5.953243       1.994714
# 1418     6.863803    5.916202       1.670909

# %%
df_copy.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  18842.000000  18842.000000        18842.000000  18842.000000
# mean    -119.603765     35.663457           29.705658   2160.921452
# std        2.001485      2.147726           12.308236   1087.777794
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.810000     33.940000           19.000000   1388.000000
# 50%     -118.530000     34.270000           30.000000   2002.000000
# 75%     -118.030000     37.730000           38.000000   2813.750000
# max     -114.490000     41.950000           52.000000   5536.000000
#
#        total_bedrooms    population    households  median_income  \
# count    18842.000000  18842.000000  18842.000000   18842.000000
# mean       444.183314   1194.483441    415.136557       3.830248
# std        219.474927    624.985534    205.011677       1.890399
# min          1.000000      3.000000      1.000000       0.499900
# 25%        286.000000    755.000000    269.000000       2.537250
# 50%        412.000000   1097.500000    386.000000       3.505200
# 75%        574.000000   1545.000000    540.000000       4.692300
# max       1131.000000   3795.000000   1059.000000      15.000100
#
#        median_house_value
# count        18842.000000
# mean            20.460524
# std             11.538565
# min              1.499900
# 25%             11.700000
# 50%             17.725000
# 75%             26.180000
# max             50.000100

# %%
def main(df,test_df):
    from sklearn.preprocessing import PolynomialFeatures


    X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
    y = df[["median_house_value"]]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    #poly = PolynomialFeatures(degree=2)
    #X_train_poly = poly.fit_transform(X_train_scaled)
    #X_test_poly = poly.transform(X_test_scaled)


    predict_model_result = {}

    def Model_predict():
        from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
        from sklearn.linear_model import LinearRegression,Ridge,Lasso
        model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
        model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
        Results = {}
        for i in range(len(model_lst)):
            model = model_lst[i]()
            model.fit(X_train_scaled,y_train)
            y_pred_train = model.predict(X_train_scaled)
            y_pred_test = model.predict(X_test_scaled)
            # Performance Metrics for testing data
            mse = mean_squared_error(y_test,y_pred_test)
            mae = mean_absolute_error(y_test,y_pred_test)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_test,y_pred_test)
            predict_model_result[str(model_name[i])+"TESTING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

            # Performance Metrics for training data
            mse = mean_squared_error(y_train,y_pred_train)
            mae = mean_absolute_error(y_train,y_pred_train)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_train,y_pred_train)
            predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
            # Checking for random data
            new_pred = model.predict(scaler.transform(test_df))
            print(new_pred)

    Model_predict()

    print("-----MODEL DETAILS: ------")
    for item in predict_model_result.items():
        print(item)

main(df_copy,li)
# Out:
# [[60.20285364]]
# [[60.22100373]]
# [70.91372686]
# [53.92430284]
# -----MODEL DETAILS: ------
# ('lin_regTESTING', {'mse': 45.06389216455565, 'mae': 4.9494195396535225, 'rmse': 6.712964484082695, 'r2_score': 0.6643908304354399})
# ('lin_regTRAINING', {'mse': 47.00573976122727, 'mae': 5.024424457574998, 'rmse': 6.856073202732543, 'r2_score': 0.6458947742700183})
# ('Ridge_regTESTING', {'mse': 45.06364571653123, 'mae': 4.949355121234649, 'rmse': 6.7129461279330425, 'r2_score': 0.6643926658343112})
# ('Ridge_regTRAINING', {'mse': 47.00575206152309, 'mae': 5.024350801366383, 'rmse': 6.856074099768985, 'r2_score': 0.6458946816090145})
# ('Lasso_regTESTING', {'mse': 65.67641026037762, 'mae': 6.176048857618695, 'rmse': 8.104098361963386, 'r2_score': 0.5108810080811618})
# ('Lasso_regTRAINING', {'mse': 66.76173802495721, 'mae': 6.15090222266847, 'rmse': 8.170785643067452, 'r2_score': 0.4970682211674624})
# ('Elastic_regTESTING', {'mse': 71.81095184264358, 'mae': 6.5938727695606225, 'rmse': 8.47413428278332, 'r2_score': 0.46519457694544064})
# ('Elastic_regTRAINING', {'mse': 72.7715254094065, 'mae': 6.550097744507308, 'rmse': 8.530622803137323, 'r2_score': 0.4517950879465069})

# %%
def main(df,test_df):
    from sklearn.preprocessing import PolynomialFeatures


    X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
    y = df[["median_house_value"]]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    #poly = PolynomialFeatures(degree=2)
    #X_train_poly = poly.fit_transform(X_train_scaled)
    #X_test_poly = poly.transform(X_test_scaled)


    predict_model_result = {}

    def Model_predict():
        from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
        from sklearn.linear_model import LinearRegression,Ridge,Lasso
        model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
        model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]
        Results = {}
        for i in range(len(model_lst)):
            model = model_lst[i]()
            model.fit(X_train_scaled,y_train)
            y_pred_train = model.predict(X_train_scaled)
            y_pred_test = model.predict(X_test_scaled)
            # Performance Metrics for testing data
            mse = mean_squared_error(y_test,y_pred_test)
            mae = mean_absolute_error(y_test,y_pred_test)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_test,y_pred_test)
            predict_model_result[str(model_name[i])+"TESTING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

            # Performance Metrics for training data
            mse = mean_squared_error(y_train,y_pred_train)
            mae = mean_absolute_error(y_train,y_pred_train)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_train,y_pred_train)
            predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
            # Checking for random data
            new_pred = model.predict(scaler.transform(test_df))
            print(new_pred)

    Model_predict()

    print("-----MODEL DETAILS: ------")
    for item in predict_model_result.items():
        print(item)

main(df_copy,li)

# %%
def main(df,test_df):
    from sklearn.preprocessing import PolynomialFeatures


    X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
    y = df["median_house_value"]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    #poly = PolynomialFeatures(degree=2)
    #X_train_poly = poly.fit_transform(X_train_scaled)
    #X_test_poly = poly.transform(X_test_scaled)
    VALUES = []
    predict_model_result = {}
    cross_valid_result = {}

    def Model_predict():
        from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
        from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
        from sklearn.linear_model import RidgeCV,LassoCV,ElasticNetCV
        model_lst = [LinearRegression,Ridge,Lasso,ElasticNet]
        model_name = ["lin_reg","Ridge_reg","Lasso_reg","Elastic_reg"]

        cv_model_lst = [RidgeCV,LassoCV,ElasticNetCV]
        cv_model_name = ["Ridge_CV","Lasso_CV","Elastic_CV"]
        print("----------------------------------------------------")
        print("-----BEFORE CV values: ------")
        Results = {}
        for i in range(len(model_lst)):
            model = model_lst[i]()
            model.fit(X_train_scaled,y_train)
            y_pred_train = model.predict(X_train_scaled)
            y_pred_test = model.predict(X_test_scaled)
            # Performance Metrics for testing data
            mse = mean_squared_error(y_test,y_pred_test)
            mae = mean_absolute_error(y_test,y_pred_test)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_test,y_pred_test)
            predict_model_result[str(model_name[i])+"TESTING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}

            # Performance Metrics for training data
            mse = mean_squared_error(y_train,y_pred_train)
            mae = mean_absolute_error(y_train,y_pred_train)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_train,y_pred_train)
            predict_model_result[str(model_name[i])+"TRAINING"] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
            # Checking for random data
            new_pred = model.predict(scaler.transform(test_df))
            print(new_pred)
            VALUES.append(float(new_pred[0]))
        print("----------------------------------------------------")
        print("-----AFTER CV values: ------")
        for i in range(len(cv_model_lst)):
            model = cv_model_lst[i]()
            model.fit(X_train_scaled,y_train)
            y_pred = model.predict(X_test_scaled)
            # Performance Metrics
            mse = mean_squared_error(y_test,y_pred)
            mae = mean_absolute_error(y_test,y_pred)
            rmse = np.sqrt(mse)
            n_score = r2_score(y_test,y_pred)
            cross_valid_result[str(cv_model_name[i])] = {"mse":float(mse),"mae":float(mae),"rmse":float(rmse),"r2_score":float(n_score)}
            new_pred = model.predict(scaler.transform(test_df))
            print(new_pred)
            VALUES.append(float(new_pred[0]))
            

    Model_predict()


    print("-----MODEL DETAILS: ------")
    for item in predict_model_result.items():
        print(item)

    print("-----CV DETAILS: ------")
    for item in cross_valid_result.items():
                print(item)
    print("The predicted value list: ",VALUES)
    print(f"The average predicted values is: { np.average(VALUES)}")
    final_value = np.average(VALUES)
main(df_copy,li)
# Out:
# ----------------------------------------------------
# -----BEFORE CV values: ------
# [60.20285364]
# [60.22100373]
# [70.91372686]
# [53.92430284]
# ----------------------------------------------------
# -----AFTER CV values: ------
# [60.22100373]
# [60.08452515]
# [61.75588504]
# -----MODEL DETAILS: ------
# ('lin_regTESTING', {'mse': 45.06389216455565, 'mae': 4.9494195396535225, 'rmse': 6.712964484082695, 'r2_score': 0.6643908304354399})
# ('lin_regTRAINING', {'mse': 47.00573976122727, 'mae': 5.024424457574998, 'rmse': 6.856073202732543, 'r2_score': 0.6458947742700183})
# ('Ridge_regTESTING', {'mse': 45.06364571653123, 'mae': 4.949355121234649, 'rmse': 6.7129461279330425, 'r2_score': 0.6643926658343112})
# ('Ridge_regTRAINING', {'mse': 47.00575206152309, 'mae': 5.024350801366383, 'rmse': 6.856074099768985, 'r2_score': 0.6458946816090145})
# ('Lasso_regTESTING', {'mse': 65.67641026037762, 'mae': 6.176048857618695, 'rmse': 8.104098361963386, 'r2_score': 0.5108810080811618})
# ('Lasso_regTRAINING', {'mse': 66.76173802495721, 'mae': 6.15090222266847, 'rmse': 8.170785643067452, 'r2_score': 0.4970682211674624})
# ('Elastic_regTESTING', {'mse': 71.81095184264358, 'mae': 6.5938727695606225, 'rmse': 8.47413428278332, 'r2_score': 0.46519457694544064})
# ('Elastic_regTRAINING', {'mse': 72.7715254094065, 'mae': 6.550097744507308, 'rmse': 8.530622803137323, 'r2_score': 0.4517950879465069})
# -----CV DETAILS: ------
# ('Ridge_CV', {'mse': 45.063645716555115, 'mae': 4.949355121238384, 'rmse': 6.7129461279348215, 'r2_score': 0.6643926658341333})
# ('Lasso_CV', {'mse': 45.06124055339378, 'mae': 4.949786814811295, 'rmse': 6.712766981907966, 'r2_score': 0.6644105780643573})
# ('Elastic_CV', {'mse': 45.19146610583625, 'mae': 4.954641044756552, 'rmse': 6.722459825527873, 'r2_score': 0.6634407353052874})
# The predicted value list:  [60.202853643157354, 60.221003734285475, 70.91372685957529, 53.92430283807238, 60.221003734447805, 60.08452514583793, 61.75588503669104]
# The average predicted values is: 61.04618585600961

# %%
import pandas as pd
df  = pd.read_csv("Final_csv.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18842 entries, 0 to 18841
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           18842 non-null  float64
#  1   latitude            18842 non-null  float64
#  2   housing_median_age  18842 non-null  int64
#  3   total_rooms         18842 non-null  int64
#  4   total_bedrooms      18842 non-null  int64
#  5   population          18842 non-null  int64
#  6   households          18842 non-null  int64
#  7   median_income       18842 non-null  float64
#  8   median_house_value  18842 non-null  float64
# dtypes: float64(4), int64(5)
# memory usage: 1.3 MB

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
scaler=StandardScaler()
model = ElasticNetCV()

X = df[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
y = df["median_house_value"]
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75,test_size=0.25,random_state=42)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model.fit(X_train_scaled,y_train)
y_pred_train = model.predict(X_train_scaled)
y_pred_test = model.predict(X_test_scaled)
# Performance Metrics for testing data
mse = mean_squared_error(y_test,y_pred_test)
mae = mean_absolute_error(y_test,y_pred_test)
rmse = np.sqrt(mse)
n_score = r2_score(y_test,y_pred_test)

print(f"mse: {mse}")
print(f"mae: {mae}")
print(f"rmse: {rmse}")
print(f"r2 score: {n_score}")
# Out:
# mse: 48.62693105814424
# mae: 5.1498127150418584
# rmse: 6.9733013026933115
# r2 score: 0.6459347578599139

# %%
scaler
# Out:
# StandardScaler()

# %%
import pickle
pickle.dump(scaler,open("scaler.pkl"),"wb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[168], line 2
#       1 import pickle
# ----> 2 pickle.dump(scaler,open("scaler.pkl"),"wb")
#
# File ~/Projects/California_House_price/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scaler.pkl'

# %%
import pickle

with open("models/pickle.pkl","wb") as file:
    pickle.dump(scaler,file)

# %%
import pickle

with open("models/scaler.pkl","wb") as file:
    pickle.dump(scaler,file)
import pickle

with open("models/ElasticNet.pkl","wb") as file:
    pickle.dump(model,file)

# %%
model
# Out:
# ElasticNetCV()

# %%
df_copy.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_copy.info()
#
# NameError: name 'df_copy' is not defined
